# %%
from image_processing import *

# %matplotlib inline

# %% [markdown]
# ## 2.1

# %%
#from skimage.viewer import ImageViewer as IV

#viewer = IV(wombats)
#viewer.show()

# %%
imshow(wombats)

# %% [markdown]
# ## 2.2

# %%
backyard.shape
# Out:
# (643, 482, 3)

# %%
backyard[99, 199, :]
# Out:
# Array([114, 126,  58], dtype=uint8)

# %% [markdown]
# ## 2.3

# %%
emu.shape
# Out:
# (384, 331, 4)

# %%
emu[108, 60, :]
# Out:
# Array([148, 138, 130, 255], dtype=uint8)

# %%
np.set_printoptions(precision=4)
emu[108, 60, :].astype(float) / 255
# Out:
# Array([0.5804, 0.5412, 0.5098, 1.    ])

# %% [markdown]
# ## 2.4

# %%
# !exiftool read/cassowary.png
# Out:
# ExifTool Version Number         : 11.01
# File Name                       : cassowary.png
# Directory                       : read
# File Size                       : 21 MB
# File Modification Date/Time     : 2015:06:26 15:18:54+08:00
# File Access Date/Time           : 2019:04:24 19:53:00+08:00
# File Inode Change Date/Time     : 2019:04:24 19:52:46+08:00
# File Permissions                : rw-r--r--
# File Type                       : PNG
# File Type Extension             : png
# MIME Type                       : image/png
# Image Width                     : 4000
# Image Height                    : 2248
# Bit Depth                       : 8
# Color Type                      : RGB
# Compression                     : Deflate/Inflate
# Filter                          : Adaptive
# Interlace                       : Noninterlaced
# Background Color                : 255 255 255
# Pixels Per Unit X               : 7086
# Pixels Per Unit Y               : 7086
# ...

# %%
a = 23
b = uint8(a)
# %whos int uint8
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      23
# b          uint8    23

# %% [markdown]
# ## 2.5

# %%
imsave("cameraman.png", cameraman)
