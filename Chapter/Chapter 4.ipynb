# %%
from image_processing import *

# %matplotlib inline

# %% [markdown]
# ## 4.2

# %%
x = arange(0, 255, 32, dtype=uint8)
x
# Out:
# array([  0,  32,  64,  96, 128, 160, 192, 224], dtype=uint8)

# %%
x + 100
# Out:
# array([100, 132, 164, 196, 228,   4,  36,  68], dtype=uint8)

# %%
x - 100
# Out:
# array([156, 188, 220, 252,  28,  60,  92, 124], dtype=uint8)

# %%
imshow(blocks + 128)

# %%
plt.subplot(1, 2, 1)
imshow(add(blocks, 128))
plt.subplot(1, 2, 2)
imshow(add(blocks, -128))

# %%
imshow(255 - blocks)

# %% [markdown]
# ## 4.3

# %%
imshow(chickens)

# %%
imhist(chickens)

# %%
plt.subplot(1, 2, 1)
imshow(adjust_gamma(chickens, 0.5))
plt.subplot(1, 2, 2)
imshow(adjust_gamma(chickens, 0.25))

# %%
imhist(chickens, True)

# %%
imshow(equalize_hist(chickens))

# %%
sunset = img_as_ubyte(rgb2gray(sunset))

# %%
imshow(sunset)

# %%
imhist(sunset)

# %%
imshow(equalize_hist(sunset))

# %%
imhist(sunset, True)
