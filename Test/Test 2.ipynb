# %%
import util.nbutil
from util.imutil import *
import cv2 as cv
# %matplotlib inline

# %%
c = imread("test.png")
matplot([c])

# %%
ca = imread("cameraman.png")
#matplot([convolve(ca, ones((1, 7)) / 7)])
#matplot([uniform_filter(ca, 7, mode="constant")])

# %%
m = ones((6,  6)) / 36#ones((7, 7)) / 49
c1 = deblur(c, m, "con", 0.009)
matplot([c, c1])

# %% [markdown]
# ===

# %%
edge = roberts(c1)
t = threshold_otsu(edge)
matplot([c1, edge])

# %%
edge = prewitt(c1)
matplot([c1, edge])

# %%
edge = sobel(c1)
matplot([c1, edge])

# %%
edge = abs(ndi.laplace(c1))
matplot([c1, edge])

# %%
edge = cv.Canny(c1, 200, 255)
matplot([c1, edge])
